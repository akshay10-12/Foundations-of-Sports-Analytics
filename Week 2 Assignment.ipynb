# %% [markdown]
# ## Part 1- Data Coding and Merging

# %%
#Import Libraries

import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import NHL Team Data and Display
NHL_Team=pd.read_csv("Assignment Data/Week 2/NHL_team.csv")
display(NHL_Team)
# Out:
#     Unnamed: 0    tid                   name           tname         lname  \
# 0            1      1    Toronto Maple Leafs     Maple Leafs       Toronto
# 1            2      2     Montréal Canadiens       Canadiens      Montréal
# 2            3      4          Winnipeg Jets            Jets      Winnipeg
# 3            4      5    Washington Capitals        Capitals    Washington
# 4            5      6     Chicago Blackhawks      Blackhawks       Chicago
# 5            6      7        St. Louis Blues           Blues     St. Louis
# 6            7      8    Pittsburgh Penguins        Penguins    Pittsburgh
# 7            8     10        Edmonton Oilers          Oilers      Edmonton
# 8            9     11         Calgary Flames          Flames       Calgary
# 9           10     14    Philadelphia Flyers          Flyers  Philadelphia
# 10          11     16        San Jose Sharks          Sharks      San Jose
# 11          12     17         Buffalo Sabres          Sabres       Buffalo
# 12          13     18      Detroit Red Wings       Red Wings       Detroit
# 13          14     19    Nashville Predators       Predators     Nashville
# 14          15     20          Boston Bruins          Bruins        Boston
# 15          16     21          Anaheim Ducks           Ducks       Anaheim
# 16          17     22     Colorado Avalanche       Avalanche      Colorado
# 17          18     25    Tampa Bay Lightning       Lightning     Tampa Bay
# 18          19     28       New York Rangers         Rangers      New York
# 19          20     29      New Jersey Devils          Devils    New Jersey
# 20          21     32        Ottawa Senators        Senators        Ottawa
# 21          22     35         Minnesota Wild            Wild     Minnesota
# 22          23     41      Los Angeles Kings           Kings   Los Angeles
# 23          24     43        Arizona Coyotes         Coyotes       Arizona
# 24          25     45       Florida Panthers        Panthers       Florida
# 25          26     46           Dallas Stars           Stars        Dallas
# 26          27     50        Phoenix Coyotes         Coyotes       Phoenix
# 27          28     51     New York Islanders       Islanders      New York
# 28          29     52  Columbus Blue Jackets    Blue Jackets      Columbus
# 29          30     53      Vancouver Canucks         Canucks     Vancouver
# 30          31     59   Vegas Golden Knights  Golden Knights         Vegas
# 31          32     66    Carolina Hurricanes      Hurricanes      Carolina
# 32          33  11366      Atlanta Thrashers       Thrashers       Atlanta
#
#    tricode abbr         sname
# 0      TOR  TOR       Toronto
# 1      MTL  MTL      Montréal
# 2      WPG  WPG      Winnipeg
# 3      WSH  WSH    Washington
# 4      CHI  CHI       Chicago
# 5      STL  STL      St Louis
# 6      PIT  PIT    Pittsburgh
# 7      EDM  EDM      Edmonton
# 8      CGY  CGY       Calgary
# 9      PHI  PHI  Philadelphia
# 10     SJS  SJS      San Jose
# 11     BUF  BUF       Buffalo
# 12     DET  DET       Detroit
# 13     NSH  NSH     Nashville
# 14     BOS  BOS        Boston
# 15     ANA  ANA       Anaheim
# 16     COL  COL      Colorado
# 17     TBL  TBL     Tampa Bay
# 18     NYR  NYR    NY Rangers
# 19     NJD  NJD    New Jersey
# 20     OTT  OTT        Ottawa
# 21     MIN  MIN     Minnesota
# 22     LAK  LAK   Los Angeles
# 23     ARI  ARI       Arizona
# 24     FLA  FLA       Florida
# 25     DAL  DAL        Dallas
# 26     PHX  PHX       Phoenix
# 27     NYI  NYI  NY Islanders
# 28     CBJ  CBJ      Columbus
# 29     VAN  VAN     Vancouver
# 30     VGK  VGK         Vegas
# 31     CAR  CAR      Carolina
# 32     ATL  ATL       Atlanta

# %% [markdown]
# ### 1. Import the “NHL_Team.csv” data file and name the dataframe as “NHL_Team” in Jupyter Notebook.
# a) Delete the following variables: “Unnamed:0”, “abbr”, “tname”, “lname”, and “sname”. <br>
# b) Rename the variable “name” to “team_name”.

# %%
NHL_Team.drop(['Unnamed: 0', 'abbr', 'tname', 'lname', 'sname'], axis = 1, inplace = True)
NHL_Team.rename(columns = {'name':'team_name'}, inplace = True)
NHL_Team.head()
# Out:
#    tid            team_name tricode
# 0    1  Toronto Maple Leafs     TOR
# 1    2   Montréal Canadiens     MTL
# 2    4        Winnipeg Jets     WPG
# 3    5  Washington Capitals     WSH
# 4    6   Chicago Blackhawks     CHI

# %% [markdown]
# ### 2. Import the “NHL_competition.csv” data file and name the dataframe as “NHL_Competition” in Jupyter Notebook.
# a) Delete the following variables: “Unnamed: 0”, “tz”, “start”, and “end” <br>
# b) Rename the variable “name” to “competition_name”.

# %%
#Import NHL Competition Data and Display Head
NHL_Competition=pd.read_csv("Assignment Data/Week 2/NHL_competition.csv")
NHL_Competition.head()
# Out:
#    Unnamed: 0  comp_id  year  type                     name  tz  start  end
# 0           1        1  2013     2  2013 NHL Regular Season  ET    NaN  NaN
# 1           2        2  2017     2  2017 NHL Regular Season  ET    NaN  NaN
# 2           3     2453  2013     3         2013 NHL Playoff  ET    NaN  NaN
# 3           4     2541  2017     3         2017 NHL Playoff  ET    NaN  NaN
# 4           5     2661  2012     2  2012 NHL Regular Season  ET    NaN  NaN

# %%
NHL_Competition.drop(['Unnamed: 0', 'tz', 'start', 'end'], axis = 1, inplace = True)
NHL_Competition.rename(columns = {'name':'competition_name'}, inplace = True)

# %%
NHL_Competition.head()
# Out:
#    comp_id  year  type         competition_name
# 0        1  2013     2  2013 NHL Regular Season
# 1        2  2017     2  2017 NHL Regular Season
# 2     2453  2013     3         2013 NHL Playoff
# 3     2541  2017     3         2017 NHL Playoff
# 4     2661  2012     2  2012 NHL Regular Season

# %% [markdown]
# ### 3. Import the “NHL_game.csv” data file and name the dataframe as “NHL_Game” in Jupyter Notebook.
# a) Delete the following variables: “X”, “period”, and “status”.

# %%
#Import NHL Game Data and Display Head
NHL_Game=pd.read_csv("Assignment Data/Week 2/NHL_game.csv")
NHL_Game.head()
# Out:
#    X  gid  comp_id        date  ascore  hscore  period  status home_away  tid
# 0  1   37        2   10/7/2017     NaN     NaN     NaN     NaN      away   25
# 1  2   67        2   10/9/2017     NaN     NaN     NaN     NaN      away   29
# 2  3  154        1  10/14/2013     NaN     NaN     NaN     NaN      away   29
# 3  4  278        1  10/24/2013     NaN     NaN     NaN     NaN      away   53
# 4  5  291        1  10/25/2013     NaN     NaN     NaN     NaN      away    5

# %%
NHL_Game.drop(['X', 'status', 'period'], axis = 1, inplace = True)
NHL_Game.head()
# Out:
#    gid  comp_id        date  ascore  hscore home_away  tid
# 0   37        2   10/7/2017     NaN     NaN      away   25
# 1   67        2   10/9/2017     NaN     NaN      away   29
# 2  154        1  10/14/2013     NaN     NaN      away   29
# 3  278        1  10/24/2013     NaN     NaN      away   53
# 4  291        1  10/25/2013     NaN     NaN      away    5

# %%
#Import NHL PPPK Data and Display Head
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_PPPK.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name
# 0     ANA   35   27   9.0  2010 NHL Playoff
# 1     BOS  126  116  22.0  2010 NHL Playoff
# 2     BUF   48   46  13.0  2010 NHL Playoff
# 3     CHI   27   39   6.0  2010 NHL Playoff
# 4     DET   59   55   6.0  2010 NHL Playoff

# %% [markdown]
# ### 4. Merge the dataframe “NHL_Team” into the dataframe “NHL_Game” by “tid.” Continue to name the merged dataframe as “NHL_Game.”

# %%
NHL_Game = pd.merge(NHL_Team, NHL_Game, on = ['tid'])
NHL_Game.head()
# Out:
#    tid            team_name tricode   gid  comp_id        date  ascore  \
# 0    1  Toronto Maple Leafs     TOR   741        1  11/28/2013     NaN
# 1    1  Toronto Maple Leafs     TOR   782        1   12/1/2013     NaN
# 2    1  Toronto Maple Leafs     TOR  5225     5181   4/25/2017     NaN
# 3    1  Toronto Maple Leafs     TOR  6557     5385    1/7/2016     NaN
# 4    1  Toronto Maple Leafs     TOR  6914     5385    2/7/2016     NaN
#
#    hscore home_away
# 0     NaN      away
# 1     NaN      away
# 2     NaN      away
# 3     NaN      away
# 4     NaN      away

# %% [markdown]
# ### 5. Merge the dataframe “NHL_Competition” into the dataframe “NHL_Game” by “comp_id.” Continue to name the merged dataframe as “NHL_Game.”

# %%
NHL_Game = pd.merge(NHL_Competition, NHL_Game, on = ['comp_id'])
NHL_Game.head(10)
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 0        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 1        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 7        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 8        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 9        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid        date  ascore  hscore home_away
# 0     TOR   741  11/28/2013     NaN     NaN      away
# 1     TOR   782   12/1/2013     NaN     NaN      away
# 2     TOR  1003  12/17/2013     1.0     3.0      away
# 3     TOR  1552   1/26/2014     4.0     5.0      away
# 4     TOR  1811    3/2/2014     3.0     4.0      away
# 5     TOR  1940   3/11/2014     3.0     1.0      away
# 6     TOR  1522   1/24/2014     1.0     7.0      away
# 7     TOR   872   12/8/2013     5.0     3.0      away
# 8     TOR  1859    3/6/2014     3.0     2.0      away
# 9     TOR   295  10/25/2013     2.0     5.0      away

# %% [markdown]
# ### 6. In the merged “NHL_Game” dataframe, create a variable “hgd” to indicate the goal difference between home and away score (hscore – ascore) and delete observations with missing value in the variable “hgd”.

# %%
NHL_Game['hgd'] = NHL_Game['hscore'] - NHL_Game['ascore']
NHL_Game.dropna(subset = ['hgd'], inplace = True)
NHL_Game.head(10)
# Out:
#     comp_id  year  type         competition_name  tid            team_name  \
# 2         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 7         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 8         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 9         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 10        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 11        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#    tricode   gid        date  ascore  hscore home_away  hgd
# 2      TOR  1003  12/17/2013     1.0     3.0      away  2.0
# 3      TOR  1552   1/26/2014     4.0     5.0      away  1.0
# 4      TOR  1811    3/2/2014     3.0     4.0      away  1.0
# 5      TOR  1940   3/11/2014     3.0     1.0      away -2.0
# 6      TOR  1522   1/24/2014     1.0     7.0      away  6.0
# 7      TOR   872   12/8/2013     5.0     3.0      away -2.0
# 8      TOR  1859    3/6/2014     3.0     2.0      away -1.0
# 9      TOR   295  10/25/2013     2.0     5.0      away  3.0
# 10     TOR   412   11/2/2013     0.0     4.0      away  4.0
# 11     TOR   564  11/16/2013     1.0     3.0      away  2.0

# %% [markdown]
# ### 7. Drop all observations with missing values, if there is still any, from the “NHL_Game” dataframe

# %%
NHL_Game.dropna(inplace = True)
NHL_Game.head(10)
# Out:
#     comp_id  year  type         competition_name  tid            team_name  \
# 2         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 7         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 8         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 9         1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 10        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 11        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#    tricode   gid        date  ascore  hscore home_away  hgd
# 2      TOR  1003  12/17/2013     1.0     3.0      away  2.0
# 3      TOR  1552   1/26/2014     4.0     5.0      away  1.0
# 4      TOR  1811    3/2/2014     3.0     4.0      away  1.0
# 5      TOR  1940   3/11/2014     3.0     1.0      away -2.0
# 6      TOR  1522   1/24/2014     1.0     7.0      away  6.0
# 7      TOR   872   12/8/2013     5.0     3.0      away -2.0
# 8      TOR  1859    3/6/2014     3.0     2.0      away -1.0
# 9      TOR   295  10/25/2013     2.0     5.0      away  3.0
# 10     TOR   412   11/2/2013     0.0     4.0      away  4.0
# 11     TOR   564  11/16/2013     1.0     3.0      away  2.0

# %%
NHL_Game.shape
# Out:
# (18506, 13)

# %% [markdown]
# ### 8. Convert the type of the “date” variable from “object” to “datetime.”

# %%
import datetime
NHL_Game['date'] = pd.to_datetime(NHL_Game['date'])
NHL_Game['date'].head()
# Out:
# 2   2013-12-17
# 3   2014-01-26
# 4   2014-03-02
# 5   2014-03-11
# 6   2014-01-24
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ### 9. Sort the NHL games by “date” and show the first 15 observations.

# %%
NHL_Game = NHL_Game.sort_values(by = ['date'], ascending = [True])
NHL_Game.head(15)
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 14163     5662  2010     2  2010 NHL Regular Season   14
# 15794     5662  2010     2  2010 NHL Regular Season   66
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13611     5662  2010     2  2010 NHL Regular Season    2
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
# 14664     5662  2010     2  2010 NHL Regular Season   21
# 13672     5662  2010     2  2010 NHL Regular Season    5
# 15145     5662  2010     2  2010 NHL Regular Season   35
# 13770     5662  2010     2  2010 NHL Regular Season    6
# 15112     5662  2010     2  2010 NHL Regular Season   32
# 14056     5662  2010     2  2010 NHL Regular Season   10
# 14460     5662  2010     2  2010 NHL Regular Season   18
#
#                    team_name tricode   gid       date  ascore  hscore  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07     4.0     3.0
# 14163    Philadelphia Flyers     PHI  5664 2010-10-07     3.0     2.0
# 15794    Carolina Hurricanes     CAR  5666 2010-10-07     4.0     3.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07     3.0     2.0
# 13611     Montréal Canadiens     MTL  5662 2010-10-07     2.0     3.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07     2.0     3.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08     3.0     4.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08     3.0     2.0
# 14664          Anaheim Ducks     ANA  5679 2010-10-08     0.0     4.0
# 13672    Washington Capitals     WSH  5683 2010-10-08     2.0     4.0
# 15145         Minnesota Wild     MIN  5677 2010-10-08     1.0     2.0
# 13770     Chicago Blackhawks     CHI  5668 2010-10-08     3.0     4.0
# 15112        Ottawa Senators     OTT  5681 2010-10-08     2.0     1.0
# 14056        Edmonton Oilers     EDM  5670 2010-10-08     0.0     4.0
# 14460      Detroit Red Wings     DET  5679 2010-10-08     0.0     4.0
#
#       home_away  hgd
# 15183      home -1.0
# 14163      away -1.0
# 15794      away -1.0
# 13955      home -1.0
# 13611      away  1.0
# 13564      home  1.0
# 14796      home  1.0
# 15675      home -1.0
# 14664      away  4.0
# 13672      away  2.0
# 15145      away  1.0
# 13770      away  1.0
# 15112      home -1.0
# 14056      home  4.0
# 14460      home  4.0

# %%
NHL_Game.tail()
# Out:
#       comp_id  year  type  competition_name  tid             team_name  \
# 5229     2541  2017     3  2017 NHL Playoff    5   Washington Capitals
# 5367     2541  2017     3  2017 NHL Playoff   59  Vegas Golden Knights
# 5228     2541  2017     3  2017 NHL Playoff    5   Washington Capitals
# 5383     2541  2017     3  2017 NHL Playoff   59  Vegas Golden Knights
# 5212     2541  2017     3  2017 NHL Playoff    5   Washington Capitals
#
#      tricode   gid       date  ascore  hscore home_away  hgd
# 5229     WSH  2725 2018-06-03     1.0     3.0      home  2.0
# 5367     VGK  2727 2018-06-05     2.0     6.0      away  4.0
# 5228     WSH  2727 2018-06-05     2.0     6.0      home  4.0
# 5383     VGK  2730 2018-06-08     4.0     3.0      home -1.0
# 5212     WSH  2730 2018-06-08     4.0     3.0      away -1.0

# %% [markdown]
# ### 10. Create two dataframes that separate the “NHL_Game” dataframe by home and away games. Name them “NHL_Home” and “NHL_Away”, respectively.
# a) Rename variables: <br>
#      i) For away games, rename “ascore” to “goals_for”; rename “hscore” to “goals_against” <br>
#      ii) For home games, rename “hscore” to “goals_for”; rename “ascore” to “goals_against” <br>
# b) Create a “win” variable that equals to 1 if the team won the game; 0 if the team lost the game; and 0.5 if it was a draw.

# %%
NHL_Home = NHL_Game[NHL_Game['home_away'] == 'home']
NHL_Home.head(10)
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
# 15112     5662  2010     2  2010 NHL Regular Season   32
# 14056     5662  2010     2  2010 NHL Regular Season   10
# 14460     5662  2010     2  2010 NHL Regular Season   18
# 15015     5662  2010     2  2010 NHL Regular Season   29
# 15843     5662  2010     2  2010 NHL Regular Season   66
#
#                    team_name tricode   gid       date  ascore  hscore  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07     4.0     3.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07     3.0     2.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07     2.0     3.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08     3.0     4.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08     3.0     2.0
# 15112        Ottawa Senators     OTT  5681 2010-10-08     2.0     1.0
# 14056        Edmonton Oilers     EDM  5670 2010-10-08     0.0     4.0
# 14460      Detroit Red Wings     DET  5679 2010-10-08     0.0     4.0
# 15015      New Jersey Devils     NJD  5674 2010-10-08     4.0     3.0
# 15843    Carolina Hurricanes     CAR  5677 2010-10-08     1.0     2.0
#
#       home_away  hgd
# 15183      home -1.0
# 13955      home -1.0
# 13564      home  1.0
# 14796      home  1.0
# 15675      home -1.0
# 15112      home -1.0
# 14056      home  4.0
# 14460      home  4.0
# 15015      home -1.0
# 15843      home  1.0

# %%
NHL_Away = NHL_Game[NHL_Game['home_away'] == 'away']
NHL_Away.head(10)
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 14163     5662  2010     2  2010 NHL Regular Season   14  Philadelphia Flyers
# 15794     5662  2010     2  2010 NHL Regular Season   66  Carolina Hurricanes
# 13611     5662  2010     2  2010 NHL Regular Season    2   Montréal Canadiens
# 14664     5662  2010     2  2010 NHL Regular Season   21        Anaheim Ducks
# 13672     5662  2010     2  2010 NHL Regular Season    5  Washington Capitals
# 15145     5662  2010     2  2010 NHL Regular Season   35       Minnesota Wild
# 13770     5662  2010     2  2010 NHL Regular Season    6   Chicago Blackhawks
# 14336     5662  2010     2  2010 NHL Regular Season   17       Buffalo Sabres
# 14101     5662  2010     2  2010 NHL Regular Season   11       Calgary Flames
# 15381     5662  2010     2  2010 NHL Regular Season   46         Dallas Stars
#
#       tricode   gid       date  ascore  hscore home_away  hgd
# 14163     PHI  5664 2010-10-07     3.0     2.0      away -1.0
# 15794     CAR  5666 2010-10-07     4.0     3.0      away -1.0
# 13611     MTL  5662 2010-10-07     2.0     3.0      away  1.0
# 14664     ANA  5679 2010-10-08     0.0     4.0      away  4.0
# 13672     WSH  5683 2010-10-08     2.0     4.0      away  2.0
# 15145     MIN  5677 2010-10-08     1.0     2.0      away  1.0
# 13770     CHI  5668 2010-10-08     3.0     4.0      away  1.0
# 14336     BUF  5681 2010-10-08     2.0     1.0      away -1.0
# 14101     CGY  5670 2010-10-08     0.0     4.0      away  4.0
# 15381     DAL  5674 2010-10-08     4.0     3.0      away -1.0

# %%
NHL_Away.rename(columns = {'ascore':'goals_for', 'hscore':'goals_against'}, inplace = True)
NHL_Home.rename(columns = {'ascore':'goals_against', 'hscore':'goals_for'}, inplace = True)

# %%
NHL_Home.head()
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
#
#                    team_name tricode   gid       date  goals_against  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07            4.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07            3.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07            2.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08            3.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08            3.0
#
#        goals_for home_away  hgd
# 15183        3.0      home -1.0
# 13955        2.0      home -1.0
# 13564        3.0      home  1.0
# 14796        4.0      home  1.0
# 15675        2.0      home -1.0

# %%
NHL_Home['win'] = np.where(NHL_Home['goals_for'] > NHL_Home['goals_against'], 1, np.where(NHL_Home['goals_for'] == NHL_Home['goals_against'], 0.5, 0))
NHL_Away['win'] = np.where(NHL_Away['goals_for'] > NHL_Away['goals_against'], 1, np.where(NHL_Away['goals_for'] == NHL_Away['goals_against'], 0.5, 0))

# %%
NHL_Home.head()
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
#
#                    team_name tricode   gid       date  goals_against  \
# 15183         Minnesota Wild     MIN  5666 2010-10-07            4.0
# 13955    Pittsburgh Penguins     PIT  5664 2010-10-07            3.0
# 13564    Toronto Maple Leafs     TOR  5662 2010-10-07            2.0
# 14796     Colorado Avalanche     COL  5668 2010-10-08            3.0
# 15675  Columbus Blue Jackets     CBJ  5672 2010-10-08            3.0
#
#        goals_for home_away  hgd  win
# 15183        3.0      home -1.0  0.0
# 13955        2.0      home -1.0  0.0
# 13564        3.0      home  1.0  1.0
# 14796        4.0      home  1.0  1.0
# 15675        2.0      home -1.0  0.0

# %%
NHL_Away.head()
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 14163     5662  2010     2  2010 NHL Regular Season   14  Philadelphia Flyers
# 15794     5662  2010     2  2010 NHL Regular Season   66  Carolina Hurricanes
# 13611     5662  2010     2  2010 NHL Regular Season    2   Montréal Canadiens
# 14664     5662  2010     2  2010 NHL Regular Season   21        Anaheim Ducks
# 13672     5662  2010     2  2010 NHL Regular Season    5  Washington Capitals
#
#       tricode   gid       date  goals_for  goals_against home_away  hgd  win
# 14163     PHI  5664 2010-10-07        3.0            2.0      away -1.0  1.0
# 15794     CAR  5666 2010-10-07        4.0            3.0      away -1.0  1.0
# 13611     MTL  5662 2010-10-07        2.0            3.0      away  1.0  0.0
# 14664     ANA  5679 2010-10-08        0.0            4.0      away  4.0  0.0
# 13672     WSH  5683 2010-10-08        2.0            4.0      away  2.0  0.0

# %% [markdown]
# ### 11. Append the “NHL_Home” and “NHL_Away” dataframes to be the new “NHL_Game” dataframe.

# %%
NHL_Game = NHL_Home.append(NHL_Away, ignore_index = True)
NHL_Game.head(10)
# Out:
#    comp_id         competition_name       date   gid  goals_against  \
# 0     5662  2010 NHL Regular Season 2010-10-07  5666            4.0
# 1     5662  2010 NHL Regular Season 2010-10-07  5664            3.0
# 2     5662  2010 NHL Regular Season 2010-10-07  5662            2.0
# 3     5662  2010 NHL Regular Season 2010-10-08  5668            3.0
# 4     5662  2010 NHL Regular Season 2010-10-08  5672            3.0
# 5     5662  2010 NHL Regular Season 2010-10-08  5681            2.0
# 6     5662  2010 NHL Regular Season 2010-10-08  5670            0.0
# 7     5662  2010 NHL Regular Season 2010-10-08  5679            0.0
# 8     5662  2010 NHL Regular Season 2010-10-08  5674            4.0
# 9     5662  2010 NHL Regular Season 2010-10-08  5677            1.0
#
#    goals_for  hgd home_away              team_name  tid tricode  type  win  \
# 0        3.0 -1.0      home         Minnesota Wild   35     MIN     2  0.0
# 1        2.0 -1.0      home    Pittsburgh Penguins    8     PIT     2  0.0
# 2        3.0  1.0      home    Toronto Maple Leafs    1     TOR     2  1.0
# 3        4.0  1.0      home     Colorado Avalanche   22     COL     2  1.0
# 4        2.0 -1.0      home  Columbus Blue Jackets   52     CBJ     2  0.0
# 5        1.0 -1.0      home        Ottawa Senators   32     OTT     2  0.0
# 6        4.0  4.0      home        Edmonton Oilers   10     EDM     2  1.0
# 7        4.0  4.0      home      Detroit Red Wings   18     DET     2  1.0
# 8        3.0 -1.0      home      New Jersey Devils   29     NJD     2  0.0
# 9        2.0  1.0      home    Carolina Hurricanes   66     CAR     2  1.0
#
#    year
# 0  2010
# 1  2010
# 2  2010
# 3  2010
# 4  2010
# 5  2010
# 6  2010
# 7  2010
# 8  2010
# 9  2010

# %% [markdown]
# ### 12. Generate a team level dataframe that aggregates the total number of games won, the total number of “goals_for” and “goals_against” for each team in each competition (i.e. grouped by tid, competition_name and type). Name this new dataframe “NHL_Team_Stats”. Make sure to convert the indexes of the new dataframe back as  variables.

# %%
NHL_Team_Stats = NHL_Game.groupby(['tid', 'competition_name', 'type'])['win', 'goals_for', 'goals_against'].sum().reset_index() 
NHL_Team_Stats
# Out:
#        tid         competition_name  type   win  goals_for  goals_against
# 0        1  2010 NHL Regular Season     2  36.0      223.0          259.0
# 1        1  2011 NHL Regular Season     2  20.0      129.0          129.0
# 2        1         2012 NHL Playoff     3   3.0       18.0           22.0
# 3        1  2012 NHL Regular Season     2  25.0      144.0          129.0
# 4        1  2013 NHL Regular Season     2  38.0      231.0          250.0
# 5        1  2014 NHL Regular Season     2  29.0      209.0          258.0
# 6        1  2015 NHL Regular Season     2  29.0      196.0          238.0
# 7        1         2016 NHL Playoff     3   2.0       16.0           18.0
# 8        1  2016 NHL Regular Season     2  40.0      255.0          246.0
# 9        1         2017 NHL Playoff     3   3.0       20.0           28.0
# 10       1  2017 NHL Regular Season     2  47.0      268.0          232.0
# 11       2         2010 NHL Playoff     3   3.0       17.0           17.0
# 12       2  2010 NHL Regular Season     2  43.0      213.0          203.0
# 13       2  2011 NHL Regular Season     2  14.0      104.0          114.0
# 14       2         2012 NHL Playoff     3   1.0        9.0           20.0
# 15       2  2012 NHL Regular Season     2  29.0      152.0          129.0
# 16       2         2013 NHL Playoff     3  10.0       51.0           46.0
# 17       2  2013 NHL Regular Season     2  45.5      216.0          206.0
# 18       2         2014 NHL Playoff     3   6.0       25.0           29.0
# 19       2  2014 NHL Regular Season     2  49.0      223.0          188.0
# 20       2  2015 NHL Regular Season     2  35.5      211.0          229.0
# 21       2         2016 NHL Playoff     3   2.0       11.0           14.0
# 22       2  2016 NHL Regular Season     2  47.5      231.0          203.0
# 23       2  2017 NHL Regular Season     2  27.5      205.0          258.0
# 24       4  2011 NHL Regular Season     2  19.0      107.0          119.0
# 25       4  2012 NHL Regular Season     2  24.0      129.0          140.0
# 26       4  2013 NHL Regular Season     2  36.0      235.0          249.0
# 27       4         2014 NHL Playoff     3   0.0        9.0           16.0
# 28       4  2014 NHL Regular Season     2  41.5      229.0          212.0
# 29       4  2015 NHL Regular Season     2  35.0      216.0          235.0
# ..     ...                      ...   ...   ...        ...            ...
# 339     52  2013 NHL Regular Season     2  42.0      232.0          218.0
# 340     52  2014 NHL Regular Season     2  41.0      238.0          251.0
# 341     52  2015 NHL Regular Season     2  32.0      211.0          242.0
# 342     52         2016 NHL Playoff     3   1.0       13.0           21.0
# 343     52  2016 NHL Regular Season     2  47.5      240.0          188.0
# 344     52         2017 NHL Playoff     3   2.0       18.0           24.0
# 345     52  2017 NHL Regular Season     2  44.0      242.0          232.0
# 346     53         2010 NHL Playoff     3  15.0       58.0           69.0
# 347     53  2010 NHL Regular Season     2  53.0      263.0          182.0
# 348     53         2011 NHL Playoff     3   1.0        8.0           12.0
# 349     53  2011 NHL Regular Season     2  25.0      134.0          102.0
# 350     53         2012 NHL Playoff     3   0.0        8.0           15.0
# 351     53  2012 NHL Regular Season     2  26.0      128.0          122.0
# 352     53  2013 NHL Regular Season     2  34.0      191.0          216.0
# 353     53         2014 NHL Playoff     3   2.0       14.0           18.0
# 354     53  2014 NHL Regular Season     2  48.5      243.0          215.0
# 355     53  2015 NHL Regular Season     2  31.0      191.0          238.0
# 356     53  2016 NHL Regular Season     2  29.0      178.0          238.0
# 357     53  2017 NHL Regular Season     2  30.0      219.0          268.0
# 358     59         2017 NHL Playoff     3  13.0       57.0           47.0
# 359     59  2017 NHL Regular Season     2  50.5      269.0          223.0
# 360     66  2010 NHL Regular Season     2  40.0      239.0          242.0
# 361     66  2011 NHL Regular Season     2  13.0      104.0          136.0
# 362     66  2012 NHL Regular Season     2  18.0      122.0          155.0
# 363     66  2013 NHL Regular Season     2  35.0      203.0          227.0
# 364     66  2014 NHL Regular Season     2  30.0      191.0          228.0
# 365     66  2015 NHL Regular Season     2  34.0      195.0          226.0
# 366     66  2016 NHL Regular Season     2  35.5      219.0          243.0
# 367     66  2017 NHL Regular Season     2  35.5      227.0          248.0
# 368  11366  2010 NHL Regular Season     2  34.0      223.0          263.0
#
# [369 rows x 6 columns]

# %% [markdown]
# ### 13. Create a dataframe “NHL_Game_Count” that include the total number of games played by each team in each competition (i.e. grouped by tid, competition_name and type). Name this new variable in the dataframe “game_count”.

# %%
NHL_Game['count'] = 1

# %%
NHL_Game_Count = NHL_Game.groupby(['tid', 'competition_name', 'type'])['count'].sum().reset_index()
NHL_Game_Count.rename(columns = {'count':'game_count'}, inplace = True)
NHL_Game_Count.head(10)
# Out:
#    tid         competition_name  type  game_count
# 0    1  2010 NHL Regular Season     2          82
# 1    1  2011 NHL Regular Season     2          40
# 2    1         2012 NHL Playoff     3           7
# 3    1  2012 NHL Regular Season     2          46
# 4    1  2013 NHL Regular Season     2          79
# 5    1  2014 NHL Regular Season     2          78
# 6    1  2015 NHL Regular Season     2          79
# 7    1         2016 NHL Playoff     3           6
# 8    1  2016 NHL Regular Season     2          82
# 9    1         2017 NHL Playoff     3           7

# %% [markdown]
# ### 14. Merge dataframes.
# a) Merge the “NHL_Game_Count” dataframe into the “NHL_Team_Stats” dataframe by “tid”, “competition_name”, and “type”. Continue to name the merged dataframe “NHL_Team_Stats”. <br>
# b) Merge the “NHL_Team” dataframe into the “NHL_Team_Stats” dataframe by “tid”. Continue to name the merged dataframe “NHL_Team_Stats”. <br>

# %%
NHL_Team_Stats = pd.merge(NHL_Game_Count, NHL_Team_Stats, on = ['tid', 'competition_name', 'type'])
NHL_Team_Stats.head(10)
# Out:
#    tid         competition_name  type  game_count   win  goals_for  \
# 0    1  2010 NHL Regular Season     2          82  36.0      223.0
# 1    1  2011 NHL Regular Season     2          40  20.0      129.0
# 2    1         2012 NHL Playoff     3           7   3.0       18.0
# 3    1  2012 NHL Regular Season     2          46  25.0      144.0
# 4    1  2013 NHL Regular Season     2          79  38.0      231.0
# 5    1  2014 NHL Regular Season     2          78  29.0      209.0
# 6    1  2015 NHL Regular Season     2          79  29.0      196.0
# 7    1         2016 NHL Playoff     3           6   2.0       16.0
# 8    1  2016 NHL Regular Season     2          82  40.0      255.0
# 9    1         2017 NHL Playoff     3           7   3.0       20.0
#
#    goals_against
# 0          259.0
# 1          129.0
# 2           22.0
# 3          129.0
# 4          250.0
# 5          258.0
# 6          238.0
# 7           18.0
# 8          246.0
# 9           28.0

# %%
NHL_Team_Stats = pd.merge(NHL_Team, NHL_Team_Stats, on = ['tid'])
NHL_Team_Stats.head(10)
# Out:
#    tid            team_name tricode         competition_name  type  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5    1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6    1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 7    1  Toronto Maple Leafs     TOR         2016 NHL Playoff     3
# 8    1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 9    1  Toronto Maple Leafs     TOR         2017 NHL Playoff     3
#
#    game_count   win  goals_for  goals_against
# 0          82  36.0      223.0          259.0
# 1          40  20.0      129.0          129.0
# 2           7   3.0       18.0           22.0
# 3          46  25.0      144.0          129.0
# 4          79  38.0      231.0          250.0
# 5          78  29.0      209.0          258.0
# 6          79  29.0      196.0          238.0
# 7           6   2.0       16.0           18.0
# 8          82  40.0      255.0          246.0
# 9           7   3.0       20.0           28.0

# %% [markdown]
# ### 15. Import the “pp.pk.ppgf.csv” data file and name the dataframe as “NHL_PPPK” in Jupyter Notebook. Merge the “NHL_PPPK” dataframe into the “NHL_Team_Stats” dataframe by “tricode” and “competition_name”.

# %%
NHL_Team_Stats = pd.merge(NHL_Team_Stats, NHL_PPPK, on = ['tricode', 'competition_name'])
NHL_Team_Stats.head(10)
# Out:
#    tid            team_name tricode         competition_name  type  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5    1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6    1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 7    1  Toronto Maple Leafs     TOR         2016 NHL Playoff     3
# 8    1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 9    1  Toronto Maple Leafs     TOR         2017 NHL Playoff     3
#
#    game_count   win  goals_for  goals_against   pp   pk  ppgf
# 0          82  36.0      223.0          259.0  368  426  46.0
# 1          40  20.0      129.0          129.0  192  182  36.0
# 2           7   3.0       18.0           22.0   30   29   5.0
# 3          46  25.0      144.0          129.0  234  230  39.0
# 4          79  38.0      231.0          250.0  362  342  61.0
# 5          78  29.0      209.0          258.0  319  343  54.0
# 6          79  29.0      196.0          238.0  324  307  27.0
# 7           6   2.0       16.0           18.0   23   25   3.0
# 8          82  40.0      255.0          246.0  321  321  69.0
# 9           7   3.0       20.0           28.0   26   21   4.0

# %% [markdown]
# ### 16. Create new variables in the “NHL_Team_Stats” dataframe.
# a) Winning percentage (“win_pct”)=”win”/ total number of games played <br>
# b) Average goals for per game (“avg_gf”)=total number of goals for / total number of games played <br>
# c) Average goals against per game (“avg_ga”)=total number of goals against / total number of games played

# %%
NHL_Team_Stats['win_pct'] = NHL_Team_Stats['win']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_gf'] = NHL_Team_Stats['goals_for']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_ga'] = NHL_Team_Stats['goals_against']/NHL_Team_Stats['game_count']
NHL_Team_Stats.head(10)
# Out:
#    tid            team_name tricode         competition_name  type  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1    1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2    1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3    1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5    1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6    1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 7    1  Toronto Maple Leafs     TOR         2016 NHL Playoff     3
# 8    1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 9    1  Toronto Maple Leafs     TOR         2017 NHL Playoff     3
#
#    game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# 0          82  36.0      223.0          259.0  368  426  46.0  0.439024
# 1          40  20.0      129.0          129.0  192  182  36.0  0.500000
# 2           7   3.0       18.0           22.0   30   29   5.0  0.428571
# 3          46  25.0      144.0          129.0  234  230  39.0  0.543478
# 4          79  38.0      231.0          250.0  362  342  61.0  0.481013
# 5          78  29.0      209.0          258.0  319  343  54.0  0.371795
# 6          79  29.0      196.0          238.0  324  307  27.0  0.367089
# 7           6   2.0       16.0           18.0   23   25   3.0  0.333333
# 8          82  40.0      255.0          246.0  321  321  69.0  0.487805
# 9           7   3.0       20.0           28.0   26   21   4.0  0.428571
#
#      avg_gf    avg_ga
# 0  2.719512  3.158537
# 1  3.225000  3.225000
# 2  2.571429  3.142857
# 3  3.130435  2.804348
# 4  2.924051  3.164557
# 5  2.679487  3.307692
# 6  2.481013  3.012658
# 7  2.666667  3.000000
# 8  3.109756  3.000000
# 9  2.857143  4.000000

# %% [markdown]
# ### 17. In the “NHL_Competition” dataframe, the variable “type” indicates the type of competition: type=2 – regular season. Create a dataframe that contains team statistics for games only during regular seasons. Name this dataframe “NHL_Team_R_Stats”.

# %%
NHL_Team_R_Stats = NHL_Team_Stats[NHL_Team_Stats['type'] == 2]
NHL_Team_R_Stats.head(10)
# Out:
#     tid            team_name tricode         competition_name  type  \
# 0     1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1     1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 3     1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4     1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5     1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6     1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 8     1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# 10    1  Toronto Maple Leafs     TOR  2017 NHL Regular Season     2
# 12    2   Montréal Canadiens     MTL  2010 NHL Regular Season     2
# 13    2   Montréal Canadiens     MTL  2011 NHL Regular Season     2
#
#     game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# 0           82  36.0      223.0          259.0  368  426  46.0  0.439024
# 1           40  20.0      129.0          129.0  192  182  36.0  0.500000
# 3           46  25.0      144.0          129.0  234  230  39.0  0.543478
# 4           79  38.0      231.0          250.0  362  342  61.0  0.481013
# 5           78  29.0      209.0          258.0  319  343  54.0  0.371795
# 6           79  29.0      196.0          238.0  324  307  27.0  0.367089
# 8           82  40.0      255.0          246.0  321  321  69.0  0.487805
# 10          79  47.0      268.0          232.0  256  245  58.0  0.594937
# 12          79  43.0      213.0          203.0  399  363  69.0  0.544304
# 13          39  14.0      104.0          114.0  175  183  37.0  0.358974
#
#       avg_gf    avg_ga
# 0   2.719512  3.158537
# 1   3.225000  3.225000
# 3   3.130435  2.804348
# 4   2.924051  3.164557
# 5   2.679487  3.307692
# 6   2.481013  3.012658
# 8   3.109756  3.000000
# 10  3.392405  2.936709
# 12  2.696203  2.569620
# 13  2.666667  2.923077

# %% [markdown]
# ## Part 2 - Descriptive and Summary Analyses

# %% [markdown]
# ### 1. In the “NHL_Game” dataframe, calculate summary statistics for the  “goals_for” variable; calculate summary statistics for the “goals_against” variable based on whether it is home or away game.

# %%
NHL_Game['goals_for'].describe()
# Out:
# count    18506.000000
# mean         2.825894
# std          1.654729
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: goals_for, dtype: float64

# %%
NHL_Game.groupby('home_away')['goals_against'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# home_away
# away       9253.0  2.961958  1.688463  0.0  2.0  3.0  4.0  10.0
# home       9253.0  2.689830  1.608916  0.0  1.0  3.0  4.0  10.0

# %% [markdown]
# ### 2. Create a histogram of the “goals_against” variable by whether the game is home or away
# a) Make the color of the histogram green <br>
# b) Set the number of bins to be 20 <br>
# c) Make sure the two sub-histograms share the same ranges for the x-axis and y-axis. <br>

# %%
NHL_Game.hist(by = 'home_away', column = 'goals_against', color = 'green', bins = 20, sharex = True, sharey = True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f667074a0b8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f66707102e8>],
#       dtype=object)

# %% [markdown]
# ## Part 3 - Correlation Analyses

# %% [markdown]
# ### 1. In the “NHL_Team_R_Stats” dataframe, make a scatter plot to depict the relationship between the total number of goals for and the winning percentage.
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. <br>
# b) Add a regression line to the scatter plot. <br>
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. <br>
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
import seaborn as sns
plt.figure(figsize=(6,6))
sns.regplot(x = 'goals_for', y = 'win_pct', data = NHL_Team_R_Stats)
plt.xlabel('Total Goals For')
plt.ylabel('Winning Percentage')
plt.title('Relationship between Goals for and Winning Percentage')
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %% [markdown]
# ### 2. In the “NHL_Team_R_Stats” dataframe, calculate the correlation coefficient between total number of goals for and winning percentage.

# %%
NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.31566456280848143

# %% [markdown]
# Small positive value indicated that the two quantities have a weak positive linear relationship.

# %% [markdown]
# ### 3. Create a scatter plot of the total number of goals for and winning percentage similar to step 1 for regular season games. In this graph, group observations by “competition_name”.
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. <br>
# b) Add a regression line to the scatter plot. <br>
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. <br>
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
plt.figure(figsize = (10,6))
sns.lmplot(x = 'goals_for', y = 'win_pct',hue = 'competition_name', data = NHL_Team_R_Stats)
plt.xlabel('Total Goals For')
plt.ylabel('Winning Percentage')
plt.title('Relationship between Goals for and Winning Percentage')
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %% [markdown]
# ### 4. For the “NHL_Team_R_Stats” dataframe, delete observations of 2011 and 2012 seasons. Continue to name the dataframe “NHL_Team_R_Stats”.

# %%
NHL_Team_R_Stats.drop(NHL_Team_R_Stats[NHL_Team_R_Stats['competition_name'] == '2011 NHL Regular Season'].index, inplace=True)
NHL_Team_R_Stats.drop(NHL_Team_R_Stats[NHL_Team_R_Stats['competition_name'] == '2012 NHL Regular Season'].index, inplace=True)

# %%
NHL_Team_R_Stats.head()
# Out:
#    tid            team_name tricode         competition_name  type  \
# 0    1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 4    1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5    1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6    1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 8    1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
#
#    game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# 0          82  36.0      223.0          259.0  368  426  46.0  0.439024
# 4          79  38.0      231.0          250.0  362  342  61.0  0.481013
# 5          78  29.0      209.0          258.0  319  343  54.0  0.371795
# 6          79  29.0      196.0          238.0  324  307  27.0  0.367089
# 8          82  40.0      255.0          246.0  321  321  69.0  0.487805
#
#      avg_gf    avg_ga
# 0  2.719512  3.158537
# 4  2.924051  3.164557
# 5  2.679487  3.307692
# 6  2.481013  3.012658
# 8  3.109756  3.000000

# %% [markdown]
# ### 5. In the new “NHL_Team_R_Stats” dataframe, create a scatter plot of total number of goals for and winning percentage.
# a) Plot the total number of goals for on the x-axis and winning percentage on the y-axis. <br>
# b) Add a regression line to the scatter plot. <br>
# c) Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11. <br>
# d) Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

# %%
plt.figure(figsize = (6,6))
sns.regplot(x = 'goals_for', y = 'win_pct', data = NHL_Team_R_Stats)
plt.xlabel('Total Goals For')
plt.ylabel('Winning Percentage')
plt.title('Relationship between Goals for and Winning Percentage')
# Out:
# Text(0.5, 1.0, 'Relationship between Goals for and Winning Percentage')

# %% [markdown]
# ### 6. Calculate the correlation coefficient between total number of goals for and winning percentage in the updated “NHL_Team_R_Stats” dataframe.

# %%
NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.7706255321801442

# %% [markdown]
# Clearly, there is a strong positive linear relationship.

# %% [markdown]
# ## Uncomment this Section once your assignment is complete

# %%
#Save Dataframes as .csv files
NHL_Game.to_csv("NHL_Game2.csv", index=False)
NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)
